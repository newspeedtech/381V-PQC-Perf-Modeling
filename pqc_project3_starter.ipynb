# %% [markdown]
# # Project 3 — PQC Performance Modeling Starter Notebook

# %% [markdown]
# Generated 2025-08-18 15:47:23.579572

# %%
import pandas as pd, sklearn, xgboost, matplotlib
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
try:
    import oqs
    print("OQS available:", hasattr(oqs, "KeyEncapsulation"))
except ImportError:
    print("oqs not installed")
# Out:
# Pandas: 2.3.1
# Scikit-learn: 1.7.1
# OQS available: True

# %%
import pandas as pd

# Path to your collected benchmark data
CSV_PATH = "pqc_perf_data.csv"  # change if you saved elsewhere

try:
    df = pd.read_csv(CSV_PATH)
    print("Loaded rows:", len(df))
    display(df.head())
except FileNotFoundError:
    print("CSV not found at", CSV_PATH)
    print("Tip: run the pqc_benchmark_harness.py script first to create it")
# Out:
# Loaded rows: 7200
#   alg_family  param_set operation  message_bytes  concurrency  cpu_ghz  aesni  \
# 0     ML-KEM        512    keygen              0            1      0.0      0
# 1     ML-KEM        512    keygen              0            1      0.0      0
# 2     ML-KEM        512    keygen              0            1      0.0      0
# 3     ML-KEM        512    keygen              0            1      0.0      0
# 4     ML-KEM        512    keygen              0            1      0.0      0
#
#    avx2  neon           machine_id os_name  containerized  latency_ms  \
# 0     0     0  MacBook-Pro-4.local  darwin              0     12.0694
# 1     0     0  MacBook-Pro-4.local  darwin              0     11.7811
# 2     0     0  MacBook-Pro-4.local  darwin              0     12.6677
# 3     0     0  MacBook-Pro-4.local  darwin              0     12.3687
# 4     0     0  MacBook-Pro-4.local  darwin              0     11.4171
#
# ...
